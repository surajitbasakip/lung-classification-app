# %% [markdown]
# The "Lung Opacity (Non-COVID lung infection)" directory serves as a catch-all category for lung images exhibiting abnormal densities due to various infections and diseases other than COVID-19. This distinction is crucial for accurate disease classification and the development of effective diagnostic tools.

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
# Define the dataset directory and image size
dataset_dir = '/Users/freewheelin/covidLung/covid19_radiography_dataset' 
IMG_SIZE = 64  # Size to which the images will be resized

# Define the class labels (map folder names to numeric labels)
class_labels = {
    'covid': 0,
    'lung_opacity': 1,
    'normal': 2,
    'viral_pneumonia': 3
}

images = []  # List to store image data
labels = []  # List to store the corresponding labels

# Loop through each class folder and its subdirectory "images"
for class_name, label in class_labels.items():
    sub_dir = os.path.join(dataset_dir, class_name, 'images')
    
    if os.path.exists(sub_dir):
        for filename in os.listdir(sub_dir):
            img_path = os.path.join(sub_dir, filename)
            
            # Only process valid image files
            if img_path.endswith(('.jpeg', '.jpg', '.png')):
                try:
                    # Open and resize the image
                    img = Image.open(img_path)
                    img = img.resize((IMG_SIZE, IMG_SIZE))  # Resize to 64x64
                    img = img.convert('L')  # Convert to grayscale (L mode)
                    img_array = np.array(img)  # Convert to numpy array

                    # Append the image and its label
                    images.append(img_array)
                    labels.append(label)
                except Exception as e:
                    print(f"Error loading image {img_path}: {e}")
    else:
        print(f"Directory {sub_dir} not found.")

# Convert to numpy arrays
images = np.array(images)
labels = np.array(labels)

print(f"Total images loaded: {len(images)}")

# Expand dimensions for grayscale images (from (64, 64) to (64, 64, 1))
images = np.expand_dims(images, axis=-1)

# Split the dataset into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Normalize the image data to the range [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Print the shapes of the data
print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")

# Visualizing a few samples (optional)
plt.figure(figsize=(10, 10))
for i in range(25):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(x_train[i].squeeze(), cmap='gray')  # Remove extra dimension for display
    plt.title(str(y_train[i]))
    plt.axis("off")
plt.show()
# Out:
# Total images loaded: 8649
# x_train shape: (6919, 64, 64, 1), y_train shape: (6919,)
# x_test shape: (1730, 64, 64, 1), y_test shape: (1730,)

# %%
# The code below takes one row from the array and creates one element of the tensor. So, if 'x_train' has size (200,64,64,3), then
# x_train_tf has 200 elements, each of shape (64,64,3)
x_train_tf = tf.data.Dataset.from_tensor_slices(x_train)
x_test_tf = tf.data.Dataset.from_tensor_slices(x_test)
y_train_tf = tf.data.Dataset.from_tensor_slices(y_train)
y_test_tf = tf.data.Dataset.from_tensor_slices(y_test)

# %%
print(x_train_tf.element_spec)
# Out:
# TensorSpec(shape=(64, 64, 1), dtype=tf.float32, name=None)

# %%
# unique classes present in the dataset
unique_labels = set()
for elements in y_train_tf:
    unique_labels.add(elements.numpy())
print(unique_labels)
# Out:
# {0, 1, 2, 3}
# 2025-02-05 13:47:11.342692: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
plt.imshow(next(iter(x_train_tf)))

# %%
def normalize(image):
    """
    Convert the elements of the tensor into float objects and reshape into a 1D array.
    the command [-1,] means that tf will judge the length of the 1D array. If 'image' has shape (64,64,3), then the newly created
    array will have shape (64*64*3)

    Argument:
    image --Tensor

    Returns: 
    result -- Transformed tensor 
    """
    image = tf.cast(image, tf.float32)
    image = tf.reshape(image,[-1,])

    return image

# %%
# normalize the elements of x_train_tf using map
new_x_train = x_train_tf.map(normalize)
new_x_test = x_test_tf.map(normalize)

# %%
def one_hot_matrix(labels, depth=4):
    """
    creates one-hot enconding for label 'labels'.

    Arguments:
        labels -- (int) categorical labels (any number from 0 to (depth-1 ))
        depth -- (int) classes for that label

    Return:
        tf.Tensor -- A single column matrix with single one hot encoding 
        (number of column -- labels
        number of row -- depth)
    """

    #one_hot = tf.reshape(tf.one_hot(labels, depth, axis=0),(depth,))
    one_hot = tf.one_hot(labels, depth, axis=-1)

    return one_hot

# %%
# Replace each class by a one_hot_matrix
new_y_train = y_train_tf.map(one_hot_matrix)
new_y_test = y_test_tf.map(one_hot_matrix)
# notice that new_y_train will have shape (depth, minibatch_size) [depth from one_hot_matirx]

# %%
def initialize_parameters():
    """
    Initializes parameters to build a neural network with TensorFlow. The shapes are:
                        W1 : [128, 4096]
                        b1 : [128, 1]
                        W2 : [64, 128]
                        b2 : [64, 1]
                        W3 : [32, 64]
                        b3 : [32, 1]
                        W4 : [16, 32]
                        b4 : [16, 1]
                        W5 : [4, 16]
                        b5 : [4, 1]
    
    Returns:
    parameters -- a dictionary of tensors containing W1, b1, ... W5, b5
    """
    initializer = tf.keras.initializers.GlorotNormal()
    regularizer = tf.keras.regularizers.l2(0.00005)  

    W1 = tf.Variable(initializer(shape = (256, 4096)))
    b1 = tf.Variable(initializer(shape = (256, 1)))
    W2 = tf.Variable(initializer(shape = (128, 256)))
    b2 = tf.Variable(initializer(shape = (128, 1)))
    W3 = tf.Variable(initializer(shape = (64, 128)))
    b3 = tf.Variable(initializer(shape = (64, 1)))
    W4 = tf.Variable(initializer(shape = (32, 64)))
    b4 = tf.Variable(initializer(shape = (32, 1)))
    W5 = tf.Variable(initializer(shape = (16, 32)))
    b5 = tf.Variable(initializer(shape = (16, 1)))
    W6 = tf.Variable(initializer(shape = (4, 16)))
    b6 = tf.Variable(initializer(shape = (4, 1)))

    parameters = {'W1': W1,
                  'b1': b1,
                  'W2': W2,
                  'b2': b2,
                  'W3': W3,
                  'b3': b3,
                  'W4': W4,
                  'b4': b4,
                  'W5': W5,
                  'b5': b5,
                  'W6': W6,
                  'b6': b6}

    return parameters

# %%
def forward_propagation(X, parameters, dropout_rate = 0.03):
    """
    Implements the forward propagation for the model: LINEAR -> RELU -> LINEAR -> RELU -> LINEAR
    
    Arguments:
    X -- input dataset placeholder, of shape (input size, number of examples)
    parameters -- python dictionary containing your parameters "W1", "b1", ... "W5", "b5"
                  the shapes are given in initialize_parameters

    Returns:
    Z5 -- the output of the last LINEAR unit
    """

    # Retrieve the parameters from the dictionary "parameters" 
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    W3 = parameters['W3']
    b3 = parameters['b3']
    W4 = parameters['W4']
    b4 = parameters['b4']
    W5 = parameters['W5']
    b5 = parameters['b5']
    W6 = parameters['W6']
    b6 = parameters['b6']

    Z1 = tf.math.add(tf.linalg.matmul(W1, X), b1)
    A1 = tf.keras.activations.relu(Z1)
    #A1 = tf.nn.dropout(A1, rate=dropout_rate)  # Dropout after first layer
    
    Z2 = tf.math.add(tf.linalg.matmul(W2, A1), b2)
    A2 = tf.keras.activations.relu(Z2)
    #A2 = tf.nn.dropout(A2, rate=dropout_rate)  # Dropout after second layer

    Z3 = tf.math.add(tf.linalg.matmul(W3, A2), b3)
    A3 = tf.keras.activations.relu(Z3)
    #A3 = tf.nn.dropout(A3, rate=dropout_rate)  # Dropout after third layer

    Z4 = tf.math.add(tf.linalg.matmul(W4, A3), b4)
    A4 = tf.keras.activations.relu(Z4)
    #A4 = tf.nn.dropout(A4, rate=dropout_rate)  # Dropout after fourth layer

    Z5 = tf.math.add(tf.linalg.matmul(W5, A4), b5)
    A5 = tf.keras.activations.relu(Z5)
    #A5 = tf.nn.dropout(A5, rate=dropout_rate)  # Dropout after fifth layer
    
    Z6 = tf.math.add(tf.linalg.matmul(W6, A5), b6)
    
    return Z6

# %%
def compute_cost(logits, labels, parameters, lambda_l2 = 0.00005):
    """
    Computes the total loss (cross-entropy + L2 regularization).
    """
    cross_entropy = tf.reduce_sum(
        tf.keras.metrics.categorical_crossentropy(tf.transpose(labels), tf.transpose(logits), from_logits=True)
    )

    # L2 regularization
    l2_loss = sum([tf.nn.l2_loss(parameters[key]) for key in ['W1', 'W2', 'W3', 'W4', 'W5','W6']])
    cost = cross_entropy + lambda_l2 * l2_loss

    return cost

# %%
def model(X_train, Y_train, X_test, Y_test, learning_rate = 0.002,
          num_epochs = 1500, minibatch_size = 32, print_cost = True):
    """
    """

    train_acc = []
    test_acc = []
    costs = []

    parameters = initialize_parameters()

    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    W3 = parameters['W3']
    b3 = parameters['b3']
    W4 = parameters['W4']
    b4 = parameters['b4']
    W5 = parameters['W5']
    b5 = parameters['b5']
    W6 = parameters['W6']
    b6 = parameters['b6']

    # Learning rate scheduling
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=learning_rate,
        decay_steps=200,
        decay_rate=0.98,  # Reduce LR by 2% every 200 steps
        staircase=True
    )

    # define the optimizer
    #optimizer_defined = tf.keras.optimizers.Adam(learning_rate)
    optimizer_defined = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

    # keep track of model accuracy
    test_accuracy = tf.keras.metrics.CategoricalAccuracy()
    train_accuracy = tf.keras.metrics.CategoricalAccuracy()

    # zip the data into a tuple of (input, expected label)
    dataset = tf.data.Dataset.zip((X_train, Y_train))
    test_dataset = tf.data.Dataset.zip((X_test, Y_test))

    # get the number of elements of dataset using the cardiality method
    m = dataset.cardinality().numpy()

    # form minibatches from the dataset
    minibatches = dataset.batch(minibatch_size).prefetch(8)
    test_minibatches = test_dataset.batch(minibatch_size).prefetch(8)

    for epoch in range(num_epochs):
        epoch_cost = 0

        # we need to restart from 0 when start a new epoch
        train_accuracy.reset_state()
        
        for (minibatch_X, minibatch_Y) in minibatches:
            with tf.GradientTape() as tape:
                # predict
                # notice that next(iter(x_train)) has shape (12288,) and  next(iter(x_train.bathc(2))) has shape (2, 12288), 
                # that's why we need the transposr in minibatch_X
                z6 = forward_propagation(tf.transpose(minibatch_X), parameters)

                # cost
                minibatch_cost = compute_cost(z6, tf.transpose(minibatch_Y), parameters)
                #print('z3 shape:', z3.shape)
                #print('Y_shape', tf.transpose(minibatch_Y).shape)
                #print(minibatch_Y.shape, z3.shape)

            # update the accuracy of all batches
            train_accuracy.update_state(tf.transpose(z6), minibatch_Y)

            # now use the gradient tape to get the gradients and update the parameters
            trainable_variables = [W1, b1, W2, b2, W3, b3, W4, b4, W5, b5, W6, b6]
            grads = tape.gradient(minibatch_cost, trainable_variables)
            optimizer_defined.apply_gradients(zip(grads, trainable_variables))

            # After applying gradients update the dictionary 'parameters', which is used as an argument to forward_prop
            parameters['W1'], parameters['b1'] = W1, b1
            parameters['W2'], parameters['b2'] = W2, b2
            parameters['W3'], parameters['b3'] = W3, b3
            parameters['W4'], parameters['b4'] = W4, b4
            parameters['W5'], parameters['b5'] = W5, b5
            parameters['W6'], parameters['b6'] = W6, b6

            # add all the costs
            epoch_cost += minibatch_cost

        # we devide the cost of each epoch by number of samples to get the cost per sample
        epoch_cost /= m

        # print cost every 10 epoch
        if print_cost == True and epoch % 10 == 0:
            print("cost after epoch %i: %f" % (epoch, epoch_cost))
            print("train accuracy:", train_accuracy.result())

            for (minibatch_X, minibatch_Y) in test_minibatches:
                Z6 = forward_propagation(tf.transpose(minibatch_X), parameters)
                test_accuracy.update_state(tf.transpose(Z6), minibatch_Y)
            print("Test_accuracy:", test_accuracy.result())

            costs.append(epoch_cost)
            train_acc.append(train_accuracy.result())
            test_acc.append(test_accuracy.result())
            test_accuracy.reset_state() # this resets every 10 epoch

    # Save the parameters manually
    save_path = "model_parameters.npz"
    np.savez(save_path, **parameters)
    print(f"Model parameters saved to {save_path}")

    # Return the trained model along with other information
    return costs, train_acc, test_acc

# %%
costs, train_acc, test_acc = model(new_x_train, new_y_train, new_x_test, new_y_test, num_epochs=250)

# Save the trained model to a .h5 file
#trained_model.save("covid_classifier_model.h5")
#print("Model saved to covid_classifier_model.h5")
# Out:
# cost after epoch 0: 1.077508
# train accuracy: tf.Tensor(0.5257985, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.5849711, shape=(), dtype=float32)
# cost after epoch 10: 0.552590
# train accuracy: tf.Tensor(0.7673074, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.76878613, shape=(), dtype=float32)
# cost after epoch 20: 0.469929
# train accuracy: tf.Tensor(0.8093655, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.73410404, shape=(), dtype=float32)
# cost after epoch 30: 0.424593
# train accuracy: tf.Tensor(0.823963, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.7566474, shape=(), dtype=float32)
# cost after epoch 40: 0.362675
# train accuracy: tf.Tensor(0.8537361, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.76127166, shape=(), dtype=float32)
# cost after epoch 50: 0.329165
# train accuracy: tf.Tensor(0.86443126, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.7843931, shape=(), dtype=float32)
# cost after epoch 60: 0.254740
# train accuracy: tf.Tensor(0.8986848, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.79942197, shape=(), dtype=float32)
# cost after epoch 70: 0.205712
# train accuracy: tf.Tensor(0.9186299, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.7953757, shape=(), dtype=float32)
# cost after epoch 80: 0.188986
# train accuracy: tf.Tensor(0.92383295, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.79075146, shape=(), dtype=float32)
# cost after epoch 90: 0.148628
# train accuracy: tf.Tensor(0.94291085, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.80231214, shape=(), dtype=float32)
# cost after epoch 100: 0.122181
# train accuracy: tf.Tensor(0.95548487, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.7988439, shape=(), dtype=float32)
# cost after epoch 110: 0.116688
# train accuracy: tf.Tensor(0.9567857, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.7976879, shape=(), dtype=float32)
# cost after epoch 120: 0.102372
# train accuracy: tf.Tensor(0.9628559, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.8017341, shape=(), dtype=float32)
# cost after epoch 130: 0.087733
# train accuracy: tf.Tensor(0.97051597, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.81213874, shape=(), dtype=float32)
# cost after epoch 140: 0.080264
# train accuracy: tf.Tensor(0.9738402, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.8098266, shape=(), dtype=float32)
# cost after epoch 150: 0.074354
# train accuracy: tf.Tensor(0.9745628, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.80231214, shape=(), dtype=float32)
# cost after epoch 160: 0.057603
# train accuracy: tf.Tensor(0.98251194, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.7982659, shape=(), dtype=float32)
# cost after epoch 170: 0.048021
# train accuracy: tf.Tensor(0.9878595, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.8052023, shape=(), dtype=float32)
# cost after epoch 180: 0.041556
# train accuracy: tf.Tensor(0.9894493, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.8098266, shape=(), dtype=float32)
# cost after epoch 190: 0.037107
# train accuracy: tf.Tensor(0.9911837, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.8086705, shape=(), dtype=float32)
# cost after epoch 200: 0.033028
# train accuracy: tf.Tensor(0.9929181, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.81445086, shape=(), dtype=float32)
# cost after epoch 210: 0.029384
# train accuracy: tf.Tensor(0.99479693, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.8150289, shape=(), dtype=float32)
# cost after epoch 220: 0.026656
# train accuracy: tf.Tensor(0.9956641, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.816763, shape=(), dtype=float32)
# cost after epoch 230: 0.024508
# train accuracy: tf.Tensor(0.9960977, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.8202312, shape=(), dtype=float32)
# cost after epoch 240: 0.022944
# train accuracy: tf.Tensor(0.9965313, shape=(), dtype=float32)
# Test_accuracy: tf.Tensor(0.8213873, shape=(), dtype=float32)
# Model parameters saved to model_parameters.npz

# %%
# Plot the cost
plt.plot(np.squeeze(costs))
plt.ylabel('cost')
plt.xlabel('iterations (per fives)')
#plt.title("Learning rate =" + str(0.0001))
plt.show()

# %%
# Plot the train accuracy
plt.plot(np.squeeze(train_acc))
plt.ylabel('Train Accuracy')
plt.xlabel('iterations (per fives)')
#plt.title("Learning rate =" + str(0.0001))
# Plot the test accuracy
plt.plot(np.squeeze(test_acc))
plt.ylabel('Test Accuracy')
plt.xlabel('iterations (per fives)')
#plt.title("Learning rate =" + str(0.0001))
plt.show()
